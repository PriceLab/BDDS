# %% [markdown]
# # Intro
#
# Simple agenda here: we're going to load the motifs/TFs mapping and then make some pretty histograms showing the mapping

# %%
# Load the data, ggplot/ggpubr, and dplyr
library(dplyr)
library(ggpubr)

tf.motifs <- readRDS("../../trenadb/fimo/2017_08_23_Motif_TF_Map.RDS")

# %%
str(tf.motifs)
# Out:
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	13242 obs. of  2 variables:
#  $ Motif: chr  "Mmusculus-UniPROBE-Sp100.UP00049" "Mmusculus-jaspar2016-Hes1-MA1099.1" "Mmusculus-jaspar2016-Hes1-MA1099.1" "Mmusculus-jaspar2016-Hes1-MA1099.1" ...
#  $ TF   : chr  "SP140L" "HEY2" "HEY1" "HES7" ...

# %%
# Make a plot of all TFs and their # of motifs
tf.motifs %>% group_by(TF) %>%
    summarise(Frequency = n()) %>%
    arrange(desc(Frequency)) %>%
    gghistogram(x = "Frequency", 
                color = "black", 
                fill = "steelblue",
                bins = 64)
# Out:
# plot without title

# %%
# Make a plot of just Jaspar motifs
tf.motifs %>% filter(grepl("jaspar2016",Motif)) %>%
    group_by(TF) %>%
    summarise(Frequency = n()) %>%
    arrange(desc(Frequency)) %>%
    gghistogram(x = "Frequency", 
                color = "black", 
                fill = "steelblue",
                bins = 64, 
                title = "Motifs per TF")
# Out:
# plot without title

# %%
# Turn it around: how many TFs per motif?
# Make a plot of all TFs and their # of motifs
tf.motifs %>% group_by(Motif) %>%
    summarise(Frequency = n()) %>%
    arrange(desc(Frequency)) %>%
    gghistogram(x = "Frequency", 
                color = "black", 
                fill = "steelblue",
                bins = 64, 
                title = "TFs per Motif"
                )
# Out:
# plot without title

# %%
tf.motifs %>% group_by(Motif) %>%
    summarise(Frequency = n()) %>%
    arrange(desc(Frequency)) %>%
    head(20)
# Out:
#    Motif                                   Frequency
# 1  Mmusculus-jaspar2016-Alx1-MA0854.1      152
# 2  Mmusculus-jaspar2016-Alx4-MA0853.1      146
# 3  Mmusculus-jaspar2016-Arx-MA0874.1       142
# 4  Mmusculus-jaspar2016-Hoxd3-MA0912.1     121
# 5  Mmusculus-jaspar2016-Hoxb5-MA0904.1     120
# 6  Mmusculus-jaspar2016-Hoxd8-MA0910.1      88
# 7  Hsapiens-jaspar2016-MEOX1-MA0661.1       85
# 8  Hsapiens-jaspar2016-GBX1-MA0889.1        82
# 9  Hsapiens-jaspar2016-POU6F1-MA0628.1      81
# 10 Hsapiens-jaspar2016-EMX2-MA0886.1        80
# 11 Hsapiens-jaspar2016-EMX1-MA0612.1        75
# 12 Hsapiens-jaspar2016-LHX2-MA0700.1        73
# 13 Hsapiens-jaspar2016-VSX2-MA0726.1        73
# 14 Hsapiens-jaspar2016-GBX2-MA0890.1        72
# 15 Hsapiens-HOCOMOCOv10-EMX2_HUMAN.H10MO.D  70
# 16 Hsapiens-jaspar2016-LHX6-MA0658.1        69
# 17 Hsapiens-jaspar2016-ELF3-MA0640.1        68
# 18 Hsapiens-jaspar2016-HOXB2-MA0902.1       64
# 19 Hsapiens-jaspar2016-EVX2-MA0888.1        63
# 20 Hsapiens-jaspar2016-HOXA2-MA0900.1       63
