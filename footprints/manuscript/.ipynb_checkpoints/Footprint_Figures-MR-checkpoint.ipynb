# %% [markdown]
# This notebook is an initial exploration into figures we can generate using the footprint databases. Initial explorations began on 08/08/2017 and should be updated as new data become available.

# %%
library(dplyr)
library(RPostgreSQL)
library(ggpubr)
library(BiocParallel)
library(VennDiagram)
library(reshape2)
library(GenomicRanges)
library(purrr)
library(RColorBrewer)

# Load my scripts
source("./sharedFunctions.R")
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: DBI
# Loading required package: ggplot2
# Loading required package: magrittr
# Loading required package: grid
# Loading required package: futile.logger
#
# Attaching package: ‘VennDiagram’
#
# The following object is masked from ‘package:ggpubr’:
#
#     rotate
#
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colMeans, colnames,
#     colSums, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, lengths, Map, mapply, match,
#     mget, order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rowMeans, rownames, rowSums, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which, which.max, which.min
#
# Loading required package: S4Vectors
#
# Attaching package: ‘S4Vectors’
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
# Loading required package: IRanges
#
# Attaching package: ‘IRanges’
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
# Loading required package: GenomeInfoDb
#
# Attaching package: ‘purrr’
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     reduce
#
# The following object is masked from ‘package:IRanges’:
#
#     reduce
#
# The following object is masked from ‘package:magrittr’:
#
#     set_names

# %% [markdown]
# ## Figure 1: Venn Diagram Comparing Seed 16 to Seed 20
#
# The idea here is to compare the two different seeds to one another by selecting 1 chromosome in 1 tissue type.

# %%
# Step 1: Create a function that takes a data connection and fishes out info
findUniqueMotifs <- function(dbname){ 
    
    # Specify the connection
    db <- dbConnect(PostgreSQL(),
                    user = 'trena',
                    password = 'trena',
                    dbname = dbname,
                    host = 'localhost')
    #motifs <- dbGetQuery(db, "select distinct name from hits where loc like '%chrY%';")
    motifs <- dbGetQuery(db, "select distinct name from hits;")
    dbDisconnect(db)
    return(motifs)
}

# %%
# Define the footprint-reading function
# Create a function to read the files
readFootprintTable <- function(fp.path){
    tbl <- read.table(fp.path, sep = "\t", as.is = TRUE)
    colnames(tbl) <- c("chrom", "start", "end", "name", "score", "strand")
    return(tbl)
}

# %%
# New Steps 1/2: Simply find the footprints and compare between seeds
register(MulticoreParam(workers = 29, stop.on.error = TRUE, log = TRUE), default = TRUE)

lymph.16.paths <- list.files("/ssd/mrichard/data/footprints/seed16/lymphoblast/hint/")
lymph.16.paths <- file.path("/ssd/mrichard/data/footprints/seed16/lymphoblast/hint/",lymph.16.paths)

system.time(lymph.16.list <- bptry(bplapply(lymph.16.paths,
                              readFootprintTable
                              )))
# Out:
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 12
# Timestamp: 2017-09-07 15:09:11
# Success: TRUE
# Task duration:
#    user  system elapsed
#   0.368   0.000   0.368
# Memory used:
#           used (Mb) gc trigger (Mb) max used (Mb)
# Ncells  766085 41.0    1442291 77.1  1168576 62.5
# Vcells 1592691 12.2    2382972 18.2  1900645 14.6
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 11
# Timestamp: 2017-09-07 15:09:13
# Success: TRUE
# Task duration:
#    user  system elapsed
#   1.800   0.048   1.850
# Memory used:
#           used (Mb) gc trigger (Mb) max used (Mb)
# Ncells  942224 50.4    1770749 94.6  1168576 62.5
# Vcells 3247812 24.8    5078652 38.8  3275297 25.0
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 7
# Timestamp: 2017-09-07 15:09:14
# Success: TRUE
# Task duration:
#    user  system elapsed
#   3.672   0.064   3.736
# Memory used:
#           used (Mb) gc trigger  (Mb) max used (Mb)
# Ncells 1198449 64.1    2164898 115.7  1201090 64.2
# Vcells 5708091 43.6    7526423  57.5  5709220 43.6
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 17
# Timestamp: 2017-09-07 15:09:15
# Success: TRUE
# Task duration:
#    user  system elapsed
#   3.812   0.104   3.917
# Memory used:
#           used (Mb) gc trigger  (Mb) max used (Mb)
# Ncells 1480975 79.1    2637877 140.9  1483616 79.3
# Vcells 8562361 65.4   11014048  84.1  8563490 65.4
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 1
# Timestamp: 2017-09-07 15:09:17
# Success: TRUE
# Task duration:
#    user  system elapsed
#   4.568   0.148   4.714
# Memory used:
#            used (Mb) gc trigger  (Mb) max used (Mb)
# Ncells  1844701 98.6    3205452 171.2  1847340 98.7
# Vcells 12361352 94.4   17052318 130.1 12886764 98.4
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 19
# Timestamp: 2017-09-07 15:09:21
# Success: TRUE
# Task duration:
#    user  system elapsed
#   8.576   0.180   8.759
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  2468491 131.9    3886542 207.6  2483098 132.7
# Vcells 17989831 137.3   25856846 197.3 17990960 137.3
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 5
# Timestamp: 2017-09-07 15:09:26
# Success: TRUE
# Task duration:
#    user  system elapsed
#  12.972   0.232  13.202
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  3546632 189.5    5684620 303.6  3549273 189.6
# Vcells 28753574 219.4   37409858 285.5 28754703 219.4
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 4
# Timestamp: 2017-09-07 15:09:30
# Success: TRUE
# Task duration:
#    user  system elapsed
#  15.560   0.340  15.906
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  4749561 253.7    8273852 441.9  4752203 253.8
# Vcells 41708018 318.3   59567066 454.5 43806299 334.3
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 2
# Timestamp: 2017-09-07 15:09:32
# Success: TRUE
# Task duration:
#    user  system elapsed
#  16.392   0.372  16.765
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  5991799 320.0    9968622 532.4  6009089 321.0
# Vcells 52929717 403.9   71560479 546.0 52935646 403.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 3
# Timestamp: 2017-09-07 15:09:34
# Success: TRUE
# Task duration:
#    user  system elapsed
#  16.912   0.352  17.263
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  7150561 381.9   12002346 641.0  7167856 382.9
# Vcells 63417728 483.9   85952574 655.8 63423680 483.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 6
# Timestamp: 2017-09-07 15:09:36
# Success: TRUE
# Task duration:
#    user  system elapsed
#  16.040   0.368  16.409
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  8375151 447.3   14442815 771.4  8392443 448.3
# Vcells 74516374 568.6  103223088 787.6 74522323 568.6
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 8
# Node: 8
# Timestamp: 2017-09-07 15:09:39
# Success: TRUE
# Task duration:
#    user  system elapsed
#  18.988   0.428  19.422
# Memory used:
#            used  (Mb) gc trigger  (Mb) max used  (Mb)
# Ncells  9794570 523.1   14442815 771.4  9811867 524.1
# Vcells 91569660 698.7  123947705 945.7 95769917 730.7
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 9
# Timestamp: 2017-09-07 15:09:42
# Success: TRUE
# Task duration:
#    user  system elapsed
#  19.156   0.412  19.571
# Memory used:
#             used  (Mb) gc trigger   (Mb)  max used  (Mb)
# Ncells  11220144 599.3   17371378  927.8  11237437 600.2
# Vcells 104540949 797.6  148817246 1135.4 104546899 797.7
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 10
# Node: 10
# Timestamp: 2017-09-07 15:09:44
# Success: TRUE
# Task duration:
#    user  system elapsed
#  18.768   0.468  19.237
# Memory used:
#             used  (Mb) gc trigger   (Mb)  max used  (Mb)
# Ncells  12528276 669.1   20885653 1115.5  12545570 670.1
# Vcells 116507834 888.9  178660695 1363.1 116513794 889.0
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 13
# Node: 13
# Timestamp: 2017-09-07 15:09:47
# Success: TRUE
# Task duration:
#    user  system elapsed
#  17.268   0.384  17.651
# Memory used:
#             used  (Mb) gc trigger   (Mb)  max used  (Mb)
# Ncells  13689602 731.2   20885653 1115.5  13706896 732.1
# Vcells 127155062 970.2  214472834 1636.3 127161022 970.2
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 14
# Timestamp: 2017-09-07 15:09:50
# Success: TRUE
# Task duration:
#    user  system elapsed
#  14.792   0.368  15.158
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  14793953  790.1   25102783 1340.7  14811250  791.1
# Vcells 137351093 1048.0  214472834 1636.3 137357056 1048.0
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 15
# Timestamp: 2017-09-07 15:09:53
# Success: TRUE
# Task duration:
#    user  system elapsed
#  18.736   0.344  19.079
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  16084922  859.1   25102783 1340.7  16102219  860.0
# Vcells 149271208 1138.9  214472834 1636.3 149277178 1138.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 16
# Timestamp: 2017
area.2 <- nrow(lymph.20)
area.3 <- nrow(intersect(lymph.20,lymph.16))

#saveRDS(list(area.1 = area.1, area.2=area.2, area.3 = area.3), "./Fig_1_list.RDS")

# %%
# Load the list
area.list <- readRDS("./Fig_1_list.RDS")

# Make a better looking venn diagram (save it to png)
png(filename = "Figure1.png")

venn.plot <- draw.pairwise.venn(area1 = area.list$area.1,
                                area2 = area.list$area.2,
                                cross.area = area.list$area.3,
                                category = c("Seed16","Seed20"),
                                fill = c("blue","red")#,
                                # ext.text = TRUE,
                                #cat.default.pos = "text" # Switch labels to inside??
                                )
dev.off()

grid::grid.draw(venn.plot)
# Out:
# png
#   2
# plot without title

# %% [markdown]
# *** Alternate approach: find things that do/don't have overlaps using GenomicRanges ***
#
# We'll take the full list of footprints for each seed size and find the overlaps between them. Then we'll effectively take the set difference, finding how many things in each seed size don't overlap with the other one at all

# %%
# Load the data
load("/ssd/mrichard/data/all_lymph_footprints.Rdata")

# %%
# Make GRanges objects out of both:
gr.16 <- with(lymph.16, GRanges(seqnames=chrom, IRanges(start=start, end=end)))
gr.20 <- with(lymph.20, GRanges(seqnames=chrom, IRanges(start=start, end=end)))

# %%
# Find all overlaps between them
system.time(tbl.overlaps <- as.data.frame(findOverlaps(gr.16, gr.20, type="any")))
head(tbl.overlaps)
# Out:
#   queryHits subjectHits
# 1 2          1377485
# 2 2          1623876
# 3 2         11388946
# 4 2         21883234
# 5 3          8683721
# 6 3         19378581

# %%
nrow(lymph.16)
# Out:
# [1] 20738904

# %%
length(unique(tbl.overlaps$queryHits))
# Out:
# [1] 19096061

# %%
nrow(lymph.20)
# Out:
# [1] 22848631

# %%
length(unique(tbl.overlaps$subjectHits))
# Out:
# [1] 20590443

# %% [markdown]
# We can then figure out how many things DO NOT overlap in each set if we'd like; the basic idea is that ~95% of the sequences have at least 1 base of overlap. Note that it's hard to make a Venn diagram of this because the overlaps aren't 1:1, so the %'s wouldn't add up to 100%.
#
# In any case, here's what happens if we require at least 5 bases of overlap instead:

# %%
system.time(tbl.overlaps.5 <- as.data.frame(findOverlaps(gr.16, gr.20, type="any",minoverlap = 5)))
# Out:
#    user  system elapsed
#  43.812   3.000  46.815

# %% [markdown]
# We'll again compute the number of overlaps for each:

# %%
length(unique(tbl.overlaps.5$queryHits))
# Out:
# [1] 18895542

# %%
length(unique(tbl.overlaps.5$subjectHits))
# Out:
# [1] 20341970

# %% [markdown]
# Again, we're capturing like 95% of each set as being basically the same. So let's push it just a bit and require overlap of 10 bases:

# %%
system.time(tbl.overlaps.10 <- as.data.frame(findOverlaps(gr.16, gr.20, type="any",minoverlap = 10)))
# Out:
#    user  system elapsed
#  36.844   2.036  38.884

# %%
length(unique(tbl.overlaps.10$queryHits));length(unique(tbl.overlaps.10$subjectHits))
# Out:
# [1] 18430380
# [1] 19758660

# %% [markdown]
# Do it in a loop, going from 1->20 in min overlap

# %%
queries <- numeric(length = 30)
subjects <- numeric(length = 30)

for(i in 1:30){
    
    my.phrase <- sprintf("Working on overlap size %d",i)
    print(my.phrase)
    tbl <- as.data.frame(findOverlaps(gr.16,gr.20,type="any",minoverlap = i))
    queries[i] <- length(unique(tbl$queryHits))
    subjects[i] <- length(unique(tbl$subjectHits))
}
# Out:
# [1] "Working on overlap size 1"
# [1] "Working on overlap size 2"
# [1] "Working on overlap size 3"
# [1] "Working on overlap size 4"
# [1] "Working on overlap size 5"
# [1] "Working on overlap size 6"
# [1] "Working on overlap size 7"
# [1] "Working on overlap size 8"
# [1] "Working on overlap size 9"
# [1] "Working on overlap size 10"
# [1] "Working on overlap size 11"
# [1] "Working on overlap size 12"
# [1] "Working on overlap size 13"
# [1] "Working on overlap size 14"
# [1] "Working on overlap size 15"
# [1] "Working on overlap size 16"
# [1] "Working on overlap size 17"
# [1] "Working on overlap size 18"
# [1] "Working on overlap size 19"
# [1] "Working on overlap size 20"
# [1] "Working on overlap size 21"
# [1] "Working on overlap size 22"
# [1] "Working on overlap size 23"
# [1] "Working on overlap size 24"
# [1] "Working on overlap size 25"
# [1] "Working on overlap size 26"
# [1] "Working on overlap size 27"
# [1] "Working on overlap size 28"
# [1] "Working on overlap size 29"
# [1] "Working on overlap size 30"

# %%
# Grab total entries from each
total.16 <- nrow(lymph.16)
total.20 <- nrow(lymph.20)

# %%
total.16; total.20
# Out:
# [1] 20738904
# [1] 22848631

# %%
overlap.df <- data_frame(Overlap.Distance = 1:30,
                         Seed.16.hits = queries,
                         Seed.20.hits = subjects,
                         Seed.16 = Seed.16.hits/total.16,
                         Seed.20 = Seed.20.hits/total.20
                        )

overlap.df.long <- melt(overlap.df, 
                        id.vars = "Overlap.Distance", 
                        measure.vars = c("Seed.16","Seed.20"), 
                        variable.name = "Seed", 
                        value.name = "Percent")

sp <- ggscatter(data = overlap.df.long,
                x = "Overlap.Distance",
                y = "Percent",
                color = "Seed",
                palette = "jco",
                size = 3,
                xlab = "Minimum Overlap",
                ylab = "Percent with Overlap",
                title = "Lymphoblast Hint",
                legend.title = ""
               ) +
      font("xy.text", size = 16) + # Make axis tick labels bigger
      font("xylab", size = 16) + # Make axis labels bigger
      font("title", size = 20) +# Make title bigger
      font("legend.text", size = 14) # Make legend text bigger

sp
# Out:
# plot without title

# %%
# Save the figure
png("./Figure2.png")
sp
dev.off()
# Out:
# png
#   2

# %% [markdown]
# ### Complimentary figures (2.1, 2.2)
#
# Now we want to pick out a particular threshold and decide how many things overlap at that point. This has directionality, so let's map A to B, then B to A (16 to 20 and 20 to 16). We'll use minOverlap = 15 for this

# %%
# Grab the stats for 15
only.15 <- filter(overlap.df, Overlap.Distance == 15)
only.15
# Out:
#   Overlap.Distance Seed.16.hits Seed.20.hits Seed.16   Seed.20
# 1 15               10234167     10706762     0.4934768 0.4685953

# %%
# Plot with 16 as reference
# Note: we have to adjust the other total to reflect;
# B_adj = B_not + A_in
# B_not = B_tot - B_in
# Thus: B_adj = B_tot + A_in - B_in

adj.20 <- total.20 + only.15$Seed.16.hits - only.15$Seed.20.hits

png("./Figure2.1.png")
venn.plot <- draw.pairwise.venn(area1 = total.16,
                                area2 = adj.20,
                                cross.area = only.15$Seed.16.hits,
                                category = c("Seed16","Seed20"),
                                fill = c("blue","yellow")#,
                                # ext.text = TRUE,
                                #cat.default.pos = "text" # Switch labels to inside??
                                )
dev.off()
grid::grid.draw(venn.plot)
# Out:
# plot without title

# %%
# Plot with 20 as reference
adj.16 <- total.16 + only.15$Seed.20.hits - only.15$Seed.16.hits
png("./Figure2.2.png")
venn.plot <- draw.pairwise.venn(area1 = round(adj.16/1e6,1),
                                area2 = round(total.20/1e6,1),
                                cross.area = round(only.15$Seed.20.hits/1e6,1),
                                category = c("",""),
                                fill = c("blue","yellow"),
                                cat.cex = c(1.3,1.3), # Change size of labels
                                cex = c(2,2,2) # Change size of numbers inside#,
                                # ext.text = TRUE,
                                #cat.default.pos = "text" # Switch labels to inside??
                                )
dev.off()
# Out:
# png
#   2

# %%
grid::grid.draw(venn.plot)
# Out:
# plot without title

# %% [markdown]
# ### Sub-Figure exploration: Do it as %
#
# Note: this takes a little while (I'm guessing ~10-15 min for the pintersect step)

# %%
# Find the table of overlaps
tbl.overlaps <- findOverlaps(gr.16, gr.20, type="any")

# %%
# Find the intersection; this gives us the length of the range for each overlap!!!
overlaps <- pintersect(gr.16[queryHits(tbl.overlaps)], gr.20[subjectHits(tbl.overlaps)])

# %%
# Create the percent overlap for each by dividing overlap width by the subject width
percentOverlap.20 <- width(overlaps) / width(gr.20[subjectHits(tbl.overlaps)])
percentOverlap.16 <- width(overlaps) / width(gr.16[queryHits(tbl.overlaps)])

# %%
head(percentOverlap.20)
head(percentOverlap.16)
# Out:
# [1] 0.9000000 0.7692308 0.7500000 0.8461538 0.6875000 0.5416667
# [1] 0.9473684 0.5263158 0.7894737 0.5789474 0.4230769 1.0000000

# %% [markdown]
# *** WHAT DO WE DO WITH THIS NOW?????? ***

# %%
# Create a function that finds % of subject and target overlapping for a series of points, then returns a DF

createOverlapDF <- function(tbl.overlaps, percentOverlap.16, 
                            percentOverlap.20, intervals = (1:20)/20){
    
    # Create a function to find % of subject and query overlap above a threshold
    findSubjectsAndQueries <- function(tbl.overlaps, percentOverlap.16, 
                                       percentOverlap.20, threshold){
        # Find the hits over the threshold
        hits.16 <- tbl.overlaps[percentOverlap.16 >= threshold]
        queries <- length(unique(queryHits(hits.16)))
        hits.20 <- tbl.overlaps[percentOverlap.20 >= threshold]
        subjects <- length(unique(subjectHits(hits.20)))
        return(data.frame(Threshold = threshold, Queries = queries, Subjects = subjects))
        }
    
    # Run it as a multi-core process
    register(MulticoreParam(workers = 30, stop.on.error = TRUE, log = FALSE), default = TRUE)
    
    # Run the function for all invervals
    all.overlaps <- bplapply(intervals, findSubjectsAndQueries, 
                             tbl.overlaps = tbl.overlaps, 
                             percentOverlap.16 = percentOverlap.16,
                             percentOverlap.20 = percentOverlap.20
                            )
    
    # Combine the data frames and return
    full.df <- bind_rows(all.overlaps)
    
    return(full.df)
}

# %%
system.time(test.fxn <- createOverlapDF(tbl.overlaps, percentOverlap.16,
                                        percentOverlap.20, intervals = (0:100)/100))
# Out:
#    user  system elapsed
#   8.928  88.768 719.142

# %%
# Grab the number of rows in each lymph dataset (again)
total.16 <- nrow(lymph.16)
total.20 <- nrow(lymph.20)

# %% [markdown]
# Same plotting function as above, but for percent now

# %%
# Make a plotting palette
my.palette <- c("lightblue", "navyblue")

# %%
test.fxn %>% transmute(Seed.16 = Queries/total.16,
                       Seed.20 = Subjects/total.20,
                       Thresh.Percent = Threshold * 100
                     ) -> overlap.df

overlap.df.long <- melt(overlap.df, 
                        id.vars = "Thresh.Percent", 
                        measure.vars = c("Seed.16","Seed.20"), 
                        variable.name = "Seed", 
                        value.name = "Percent")

overlap.df.long$Percent <- overlap.df.long$Percent * 100

sp <- ggscatter(data = overlap.df.long,
                x = "Thresh.Percent",
                y = "Percent",
                color = "Seed",
                palette = my.palette,
                size = 0.5,
                xlab = "Minimum Overlap (%)",
                ylab = "Percent with Overlap (%)",
                title = "Lymphoblast Hint",
                legend.title = "",                
               ) +
      font("xy.text", size = 16) + # Make axis tick labels bigger
      font("xylab", size = 16) + # Make axis labels bigger
      font("title", size = 20) +# Make title bigger
      font("legend.text", size = 14) # Make legend text bigger
      

ggarrange(ggpar(sp, ylim = c(50,100)), ncol = 2, align = "h") # Change y to 0-100sp
# Out:
# plot without title

# %%
# Save the figure
ggarrange(ggpar(sp, ylim = c(50,100)), ncol = 2, align = "h") %>%
    ggexport(filename = "./minOverlap.png")
# Out:
# file saved to ./minOverlap.png

# %%
# Print out the table
#stable.p <- ggtexttable(overlap.df, rows = NULL, 
#                        theme = ttheme("mOrange"))
#stable.p
head(overlap.df)
# Out:
#   Seed.16   Seed.20   Thresh.Percent
# 1 0.9207845 0.9011675 0
# 2 0.9207845 0.9011675 1
# 3 0.9207845 0.9011675 2
# 4 0.9206847 0.9010520 3
# 5 0.9205513 0.9008900 4
# 6 0.9203454 0.9006614 5

# %% [markdown]
# ## Figure 4: Table showing the number of footprints in each database (also functions as a list of all completed databases).
#
# This is a way of grabbing the approximate number of rows; it's probably sufficiently close and it's super fast, as opposed to getting the exact count. For now, I'll make a bar chart with a table integrated into it.

# %%
# Function for finding # rows in the hits table given a db name
findApproxHits <- function(dbname, port){
    
    # Specify the connection
    db <- dbConnect(PostgreSQL(),
                    user = 'trena',
                    password = 'trena',
                    dbname = dbname,
                    host = 'localhost',
                    port = port
                   )
    numHits <- dbGetQuery(db, "select reltuples from pg_class where relname = 'hits'")[1,1]
    dbDisconnect(db)
    return(numHits)
}

# Function for getting our specific databases
findFootprintDBs <- function(port){
    
    # Specify the connection
    db <- dbConnect(PostgreSQL(),
                    user = 'trena',
                    password = 'trena',
                    dbname = 'postgres',
                    host = 'localhost',
                    port = port
                   )
    # Get all databases, then slim it down with a grep
    existing.databases <- dbGetQuery(db, "select datname from pg_database")[,1]
    important.dbs <- grep("(hint|wellington)_(20|16)",existing.databases, value = TRUE)
    
    return(important.dbs)    
}

# %%
# Generate db lists for both database sources
# First, normal port (5432)
db_list_1 <- findFootprintDBs(port = 5432)
# Next, secondary port (5433)
db_list_2 <- findFootprintDBs(port = 5433)

# %%
# Note: could parallelize via BiocParallel if needed, but I doubt it is
hits.list.1 <- sapply(db_list_1, findApproxHits, port = 5432)
hits.list.2 <- sapply(db_list_2, findApproxHits, port = 5433)

hits.list <- c(hits.list.1, hits.list.2)
hits.table <- data_frame(Name = names(hits.list),
                         Hits = hits.list, #format(hits.list,scientific = TRUE, digits = 3),
                         Hits.thousand = hits.list/1000,
                         Hits.million = hits.list/1e6,
                         Tissue = gsub("(.*)_(hint|wellington).*","\\1",Name),
                         Method = gsub(".*_(hint|wellington).*","\\1",Name)
                        )
hits.table <- hits.table %>% arrange(Method,Tissue, Hits)

# %%
# Nice plotting; see http://www.sthda.com/english/wiki/ggplot2-easy-way-to-mix-multiple-graphs-on-the-same-page
# Color palettes: https://cran.r-project.org/web/packages/ggsci/vignettes/ggsci.html
bp <- hits.table %>% ggbarplot(x = "Name",
                               y = "Hits.million",
                               ylab = "Hits (millions)",
                               color = "white",
                               palette = "jco",
                               fill = "Method",
                               x.text.angle = 90#,
                               #sort.val = "asc"
                              )
tbl <- hits.table %>% select(Name, Hits) %>% 
        arrange(desc(Hits)) %>%
        ggtexttable(rows = NULL,
                    theme = ttheme("mViolet")
                    )
bp
# Out:
# plot without title

# %%
# Two separate graphs
big.tissues <- hits.table %>% filter(Tissue %in% c("skin","brain","lymphoblast"), Method == "hint")
small.tissues <- hits.table %>% setdiff(big.tissues) %>% filter(Method == "hint")

bp.big <- big.tissues %>% ggbarplot(x = "Tissue",
                                    y = "Hits.million",
                                    ylab = "Hits (millions)",
                                    color = "white",
                                    palette = "jco",
                                    fill = "Method",
                                    x.text.angle = 90,
                                    #sort.val = "asc"
                                    )
bp.small <- small.tissues %>% ggbarplot(x = "Tissue",
                                        y = "Hits.million",
                                        ylab = "Hits (millions)",
                                        color = "white",
                                        palette = "jco",
                                        fill = "Method",
                                        x.text.angle = 90#,
                                        #sort.val = "asc"
                                        )

# %%
ggarrange(bp.big, bp.small, 
          labels = c("Skin/Brain", "Other Tissues"),
          ncol = 2, nrow = 1)
# Out:
# plot without title

# %%
# Export the above plot for now

fig4 <- ggarrange(bp.big, bp.small, 
          labels = c("Skin/Brain", "Other Tissues"),
          ncol = 2, nrow = 1)
ggexport(fig4, filename = "Figure4.png")
# Out:
# file saved to Figure4.png

# %%
bp.small
# Out:
# plot without title

# %% [markdown]
# More important operation: stack all the UNIQUE entries together. Find the unique ones using GR objects, with min overlap = 15 bp. Order of operations here:
#
# * Grab both 16 and 20 seed databases for a tissue type
# * Convert both into GR objects
# * Run the overlap to find the # of overlaps
# * Use the overlaps to take just unique hits

# %%
nrow(hits.table)
# Out:
# [1] 108

# %% [markdown]
# ## Figure 5: Visualization of brain footprint growth, with total added footprints AND new footprints with each footprint file

# %%
# Repeat function to read footprints (in case Fig.1 hasn't been run yet)
readFootprintTable <- function(fp.path){
    tbl <- read.table(fp.path, sep = "\t", as.is = TRUE)
    colnames(tbl) <- c("chrom", "start", "end", "name", "score", "strand")
    return(tbl)
}

# %%
# Using parallelization, read all the footprint files at once and time it
register(MulticoreParam(workers = 29, stop.on.error = TRUE, log = TRUE), default = TRUE)

all.paths <- list.files("./footprints/brain_hint_20/")
all.paths <- file.path("./footprints/brain_hint_20/",all.paths)

system.time(all.fp.list <- bptry(bplapply(all.paths,
                              readFootprintTable
                              )))
# Out:
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 4
# Timestamp: 2017
772127625 5890.9 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 19
# Timestamp: 2017-08-21 15:00:21
# Success: TRUE
# Task duration:
#    user  system elapsed
#  30.696   2.556  34.122
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  32337963 1727.1   51538519 2752.5  52267848 2791.5
# Vcells 514886815 3928.3  772127625 5890.9 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 20
# Timestamp: 2017-08-21 15:00:27
# Success: TRUE
# Task duration:
#    user  system elapsed
#   7.256   1.088   8.346
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  33776984 1803.9   51538519 2752.5  52267848 2791.5
# Vcells 528509808 4032.3  772127625 5890.9 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 21
# Timestamp: 2017-08-21 15:00:34
# Success: TRUE
# Task duration:
#    user  system elapsed
#   6.180   1.096   7.399
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  34996168 1869.0   51538519 2752.5  52267848 2791.5
# Vcells 540213460 4121.6  772127625 5890.9 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 22
# Timestamp: 2017-08-21 15:00:40
# Success: TRUE
# Task duration:
#    user  system elapsed
#   6.856   1.224   8.080
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  36312574 1939.4   61886222 3305.1  52267848 2791.5
# Vcells 552705823 4216.9  926633150 7069.7 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 23
# Timestamp: 2017-08-21 15:00:48
# Success: TRUE
# Task duration:
#    user  system elapsed
#   9.168   1.312  10.547
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  38077614 2033.6   61886222 3305.1  52267848 2791.5
# Vcells 569595759 4345.7  926633150 7069.7 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 24
# Timestamp: 2017-08-21 15:00:56
# Success: TRUE
# Task duration:
#    user  system elapsed
#  22.500   2.292  24.856
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  40628514 2169.8   61886222 3305.1  52267848 2791.5
# Vcells 594020275 4532.1  926633150 7069.7 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 25
# Node: 25
# Timestamp: 2017-08-21 15:01:04
# Success: TRUE
# Task duration:
#    user  system elapsed
#  11.648   2.052  14.462
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  42901379 2291.2   61886222 3305.1  52267848 2791.5
# Vcells 615325001 4694.6  926633150 7069.7 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 26
# Node: 26
# Timestamp: 2017-08-21 15:01:12
# Success: TRUE
# Task duration:
#    user  system elapsed
#   8.552   1.252   9.822
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  44572841 2380.5   74303466 3968.3  52267848 2791.5
# Vcells 631595618 4818.7  926633150 7069.7 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 27
# Node: 27
# Timestamp: 2017-08-21 15:01:20
# Success: TRUE
# Task duration:
#    user  system elapsed
#   4.136   0.860   5.002
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  45405380 2425.0   74303466 3968.3  52267848 2791.5
# Vcells 639691113 4880.5  926633150 7069.7 640658421 4887.9
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 28
# Node: 28
# Timestamp: 2017-08-21 15:01:28
# Success: TRUE
# Task duration:
#    user  system elapsed
#   9.616   1.376  10.998
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  47093147 2515.1   74303466 3968.3  52267848 2791.5
# Vcells 656163137 5006.2 1112039780 8484.2 656169135 5006.2
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 29
# Node: 29
# Timestamp: 2017-08-21 15:01:37
# Success: TRUE
# Task duration:
#    user  system elapsed
#   7.136   1.156   8.299
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48453736 2587.8   74303466 3968.3  52267848 2791.5
# Vcells 669423992 5107.3 1112039780 8484.2 669429992 5107.4
# Log messages:
# stderr and stdout:
#    user  system elapsed
# 152.352  12.912 184.606

# %%
class(all.fp.list)
# Out:
# [1] "list"

# %%
# The object is quite large...
object.size(all.fp.list)/(1024^2)
# Out:
# 5418.5 bytes

# %%
head(all.fp.list[[1]])
# Out:
#   chrom start end   name             score strand <NA>
# 1 chr1  66103 66123 chr1:66103-66123 10    .      NA
# 2 chr1  66162 66174 chr1:66162-66174 35    .      NA
# 3 chr1  66172 66183 chr1:66172-66183 34    .      NA
# 4 chr1  66195 66211 chr1:66195-66211 50    .      NA
# 5 chr1  66215 66232 chr1:66215-66232 57    .      NA
# 6 chr1  66233 66252 chr1:66233-66252 45    .      NA

# %%
# Take the first 3 columns only
system.time(reduced.fp.list <- lapply(all.fp.list,select,1:3))
# Out:
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 1
# Timestamp: 2017
# [17] 37530034 39103432 40667148 42112512 43507482 44872881 46186239 47479459
# [25] 48432543 49291771 50124749 50496358 50728882

# %%
# Now we need to figure out how many unique rows we've added for each

# Step 1: Make a function that, given an index, combines all dfs up to that index
findUniqueRows <- function(idx, db.list) {
    
    # Create a sub-list 
    sub.df <- db.list[1:idx]
    
    # Take the union and find the rows
    nrow(reduce(sub.df,union))    
}

# %%
# Step 2: Run that function with a list of indices
system.time(total.unique.fps <- bplapply(1:length(reduced.fp.list),findUniqueRows,reduced.fp.list))
# Out:
# ############### LOG OUTPUT ###############
# Task: 1
# Node: 1
# Timestamp: 2017-08-21 15:13:33
# Success: TRUE
# Task duration:
#    user  system elapsed
#       0       0       0
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48455873 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885268 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 2
# Node: 2
# Timestamp: 2017-08-21 15:14:01
# Success: TRUE
# Task duration:
#    user  system elapsed
#   5.292   0.816   6.108
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48455904 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885332 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 3
# Node: 3
# Timestamp: 2017-08-21 15:14:14
# Success: TRUE
# Task duration:
#    user  system elapsed
#  13.668   0.980  14.650
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48455931 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885392 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 4
# Node: 4
# Timestamp: 2017-08-21 15:14:26
# Success: TRUE
# Task duration:
#    user  system elapsed
#  22.724   3.156  25.882
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48455957 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885449 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 5
# Node: 5
# Timestamp: 2017-08-21 15:14:37
# Success: TRUE
# Task duration:
#    user  system elapsed
#  31.700   5.444  37.152
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48455983 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885510 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 6
# Node: 6
# Timestamp: 2017-08-21 15:14:48
# Success: TRUE
# Task duration:
#    user  system elapsed
#  43.240   7.452  50.696
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456009 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885567 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 7
# Node: 7
# Timestamp: 2017-08-21 15:14:59
# Success: TRUE
# Task duration:
#    user  system elapsed
#  56.844   9.712  66.562
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456035 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885624 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 8
# Node: 8
# Timestamp: 2017-08-21 15:15:09
# Success: TRUE
# Task duration:
#    user  system elapsed
#  69.840   3.240  73.089
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456061 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885681 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 9
# Node: 9
# Timestamp: 2017-08-21 15:15:20
# Success: TRUE
# Task duration:
#    user  system elapsed
#  83.192   3.660  86.860
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456087 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885746 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 10
# Node: 10
# Timestamp: 2017-08-21 15:15:31
# Success: TRUE
# Task duration:
#    user  system elapsed
#  97.936   4.552 102.499
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456113 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885803 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 11
# Node: 11
# Timestamp: 2017-08-21 15:15:41
# Success: TRUE
# Task duration:
#    user  system elapsed
# 123.344  22.176 145.533
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456139 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885860 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 12
# Node: 12
# Timestamp: 2017-08-21 15:15:52
# Success: TRUE
# Task duration:
#    user  system elapsed
# 141.872  28.188 170.076
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456165 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885917 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 13
# Node: 13
# Timestamp: 2017-08-21 15:16:03
# Success: TRUE
# Task duration:
#    user  system elapsed
# 158.648  10.824 169.487
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456191 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770885974 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 14
# Node: 14
# Timestamp: 2017-08-21 15:16:13
# Success: TRUE
# Task duration:
#    user  system elapsed
# 185.996  39.432 225.443
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456217 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886031 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 15
# Node: 15
# Timestamp: 2017-08-21 15:16:24
# Success: TRUE
# Task duration:
#    user  system elapsed
# 211.372  25.780 237.173
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456243 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886088 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 16
# Node: 16
# Timestamp: 2017-08-21 15:16:51
# Success: TRUE
# Task duration:
#    user  system elapsed
# 234.140  37.252 271.415
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456269 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886145 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 17
# Node: 17
# Timestamp: 2017-08-21 15:17:08
# Success: TRUE
# Task duration:
#    user  system elapsed
# 247.276  29.692 276.996
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456295 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886203 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 18
# Node: 18
# Timestamp: 2017-08-21 15:17:27
# Success: TRUE
# Task duration:
#    user  system elapsed
# 263.560  31.124 294.713
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456321 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886261 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 20
# Node: 20
# Timestamp: 2017-08-21 15:18:33
# Success: TRUE
# Task duration:
#    user  system elapsed
# 308.300  37.552 345.883
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456347 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886319 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 19
# Node: 19
# Timestamp: 2017-08-21 15:19:11
# Success: TRUE
# Task duration:
#    user  system elapsed
# 307.028  74.624 381.687
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456373 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886377 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 23
# Node: 23
# Timestamp: 2017-08-21 15:19:54
# Success: TRUE
# Task duration:
#    user  system elapsed
# 363.860  38.260 402.165
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456399 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886435 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 21
# Node: 21
# Timestamp: 2017-08-21 15:20:07
# Success: TRUE
# Task duration:
#    user  system elapsed
# 345.628  84.764 430.428
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456425 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886493 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 24
# Node: 24
# Timestamp: 2017-08-21 15:20:20
# Success: TRUE
# Task duration:
#    user  system elapsed
# 383.568  40.660 424.274
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456451 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886551 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 22
# Node: 22
# Timestamp: 2017-08-21 15:20:44
# Success: TRUE
# Task duration:
#    user  system elapsed
# 371.616  89.248 460.917
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456477 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886609 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 26
# Node: 26
# Timestamp: 2017-08-21 15:21:05
# Success: TRUE
# Task duration:
#    user  system elapsed
# 417.008  40.188 457.242
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456503 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886667 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 27
# Node: 27
# Timestamp: 2017-08-21 15:21:40
# Success: TRUE
# Task duration:
#    user  system elapsed
# 439.240  42.896 482.186
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456529 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886725 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 25
# Node: 25
# Timestamp: 2017-08-21 15:22:05
# Success: TRUE
# Task duration:
#    user  system elapsed
# 423.768  97.176 520.996
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456555 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886783 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 28
# Node: 28
# Timestamp: 2017-08-21 15:23:47
# Success: TRUE
# Task duration:
#    user  system elapsed
# 478.032 124.092 602.171
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456581 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886841 5881.4 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#
# ############### LOG OUTPUT ###############
# Task: 29
# Node: 29
# Timestamp: 2017-08-21 15:24:06
# Success: TRUE
# Task duration:
#    user  system elapsed
# 489.840 105.756 595.645
# Memory used:
#             used   (Mb) gc trigger   (Mb)  max used   (Mb)
# Ncells  48456607 2587.9   74303466 3968.3  52267848 2791.5
# Vcells 770886899 5881.5 1112039780 8484.2 960549063 7328.5
# Log messages:
# stderr and stdout:
#    user  system elapsed
# 394.128  47.584 935.592

# %%
# Now combine the 2 into one figure

all.totals <- data_frame(Idx = 1:length(reduced.fp.list),
                         Total = cumsum(total.fps.added),
                         Unique = unlist(total.unique.fps),
                         Hits = total.fps.added
                        )

# First attempt: put them on the same plot
all.totals.long <- melt(all.totals,
                        id.vars = "Idx",
                        variable.name = "Sum.Method"
                       )
saveRDS(all.totals.long, "Fig_5.RDS")
head(all.totals.long)
# Out:
#   Idx Sum.Method value
# 1 1   Total       3246144
# 2 2   Total       6090343
# 3 3   Total       8872145
# 4 4   Total      11479569
# 5 5   Total      14034247
# 6 6   Total      16476916

# %%
# Final idea: put total and unique on a line, put footprints on a bar below it

lp <- all.totals.long %>% filter(Sum.Method %in% c("Total","Unique")) %>%
   ggline(x = "Idx",
          y = "value",
          xlab = "",
          ylab = "Cumulative Footprints",
          color = "Sum.Method",
          palette = "jco",
          main = "Footprint Accumulation in Brain Hint 20"
         ) + rremove("x.text")

bp <- all.totals.long %>% filter(Sum.Method == "Hits") %>%
   ggbarplot(x = "Idx",
             y = "value",
             xlab = "",
             ylab = "Footprints in Sample",
             color = "white",
             fill = "#AA0000",
             main = ""
            ) + rremove("x.text")

ggarrange(lp, bp, nrow = 2, align = "v")
# Out:
# plot without title

# %%
fig5 <- ggarrange(lp, bp, nrow = 2, align = "v")
ggexport(fig5, filename = "Figure5.png")
# Out:
# file saved to Figure5.png

# %% [markdown]
# ## Brain Coverage figures:
#
# Re-do the brain coverage for the paper, but with `sharedFunctions` functions. Do it...
#
# 1) For all footprints
# 2) For only the filtered set

# %%
# Sequentially aggregate the footprints

# 1. Locate all footprints for brain_hint_20
all.paths <- compileFootprintPaths("brain")
hint.20.paths <- grep("brain_hint_20", all.paths, value = TRUE)
length(hint.20.paths)
# Out:
# [1] 29

# %%
# 2. In parallel, read them in
register(MulticoreParam(workers = 29, stop.on.error = TRUE, log = FALSE), default = TRUE)
system.time(hint.20.dfs <- bplapply(hint.20.paths, readFootprintTable))
# Out:
#    user  system elapsed
# 125.684   3.700 140.199

# %%
head(hint.20.dfs[[1]])
# Out:
#   chrom start end   name             score strand
# 1 chr1  66103 66123 chr1:66103-66123 10    .
# 2 chr1  66162 66174 chr1:66162-66174 35    .
# 3 chr1  66172 66183 chr1:66172-66183 34    .
# 4 chr1  66195 66211 chr1:66195-66211 50    .
# 5 chr1  66215 66232 chr1:66215-66232 57    .
# 6 chr1  66233 66252 chr1:66233-66252 45    .

# %%
# 3. Generate filtered list; Sort each list by number of rows
filtered.hint.20.dfs <- lapply(hint.20.dfs, filter, score > 200)

# First easy statistic: how many rows are in each DF (how many FPs?)
total.fps.added <- unlist(lapply(hint.20.dfs,nrow))
my.order <- order(total.fps.added, decreasing=TRUE)
hint.20.list <- hint.20.dfs[my.order]

# Re-do the statistic to get total fps for each file
total.fps.added <- unlist(lapply(hint.20.list,nrow))
total.fps.added

## Do the same for filtered
filtered.fp.added <- unlist(lapply(filtered.hint.20.dfs, nrow))
my.order <- order(filtered.fp.added, decreasing = TRUE)
filtered.list <- filtered.hint.20.dfs[my.order]

# Re-do and get statistic for filtered
filtered.fp.added <- unlist(lapply(filtered.list, nrow))
filtered.fp.added
# Out:
#  [1] 3246144 2844199 2781802 2607424 2554678 2442669 2422651 2264222 2055198
# [10] 1965971 1944207 1916970 1908625 1696582 1664324 1620888 1593480 1573398
# [19] 1563716 1445364 1394970 1365399 1313358 1293220  953084  859228  832978
# [28]  371609  232524
#  [1] 1159779 1152870 1039229 1038878  876053  786448  405912  342195  326249
# [10]  294039  289017  283606  199908  132217  131543  131234   77959   65268
# [19]   43037   31279   22628   11099    9701    8714    7994    3921    3739
# [28]    2581    1805

# %% [markdown]
# We have the number of footprints for each type (filtered and unfiltered). Now we need to figure out how much we added; we'll do so by converting our DFs to GRanges and using the "reduce", then taking the width

# %%
# Convert all the things in a list to genomic ranges
convertDFtoGR <- function(fp.df){
    my.gr <- with(fp.df, GRanges(seqnames=chrom, IRanges(start=start, end=end)))
    return(my.gr)
}

# %%
# Get the genomic ranges lists for both
all.grs <- lapply(hint.20.list, convertDFtoGR)
filtered.grs <- lapply(filtered.list, convertDFtoGR)

# %%
# Better plan: wrap it in a function, then do parallel evaluation
findChunkCoverage <- function(i, gr.list){
    
    # 1. Bite off a chunk
    sub.gr <- purrr::reduce(gr.list[1:i], c)

    # 2. Reduce it and find the sum of widths to get total coverage
    reduced.sub.gr <- GenomicRanges::reduce(sub.gr)
    total.bp <- sum(as.numeric(width(reduced.sub.gr)))
    
    # Return the total bp
    return(total.bp)
}

# %%
# Find the widths this way
register(MulticoreParam(workers = 29, stop.on.error = TRUE, log = FALSE), default = TRUE)
system.time(all.widths <- unlist(bplapply(1:29, findChunkCoverage, all.grs)))
system.time(filtered.widths <- unlist(bplapply(1:29, findChunkCoverage, filtered.grs)))
# Out:
#    user  system elapsed
#   1.168   7.892 546.890
#    user  system elapsed
#   0.300   3.664 155.817

# %%
final.df <- data_frame(Idx = 1:length(hint.20.list),
                       Total = cumsum(total.fps.added),
                       Coverage = all.widths,
                       Percent.Coverage = 100*all.widths/3253848404,
                       Hits = total.fps.added
                      )

filtered.df <- data_frame(Idx = 1:length(filtered.list),
                          Total = cumsum(filtered.fp.added),
                          Coverage = filtered.widths,
                          Percent.Coverage = 100*filtered.widths/3253848404,
                          Hits = filtered.fp.added
                         )

# %%
save(final.df, filtered.df, file = "./cumulativeCoverageAndFootprints.Rdata")

# %%
load("./cumulativeCoverageAndFootprints.Rdata")

# %%
# Grab a nice palette
darkcols <- brewer.pal(8, "Accent")

fp.plot <- final.df %>%
               ggbarplot(x = "Idx",
                         y = "Hits",
                         xlab = "Sample Number",
                         ylab = "Footprints in Sample",
                         color = "darkgray",
                         fill = "lightblue",
                         main = "") + 
#rremove("x.text") + 
geom_line(aes(x = Idx, y = Percent.Coverage*16e4), 
          color = "navyblue", lwd = 1) +
geom_point(aes(x = Idx, y = Percent.Coverage*16e4), 
          color = "navyblue", size = 2) +
scale_y_continuous(sec.axis = sec_axis(~./16e4, name = "Genome Coverage (%)"))

filtered.plot <- filtered.df %>%
               ggbarplot(x = "Idx",
                         y = "Hits",
                         xlab = "Sample Number",
                         ylab = "Footprints in Sample",
                         color = "darkgray",
                         fill = "lightblue",
                         main = "") + 
#rremove("x.text") + 
geom_line(aes(x = Idx, y = Percent.Coverage*16e4), 
          color = "navyblue", lwd = 1) +
geom_point(aes(x = Idx, y = Percent.Coverage*16e4), 
          color = "navyblue", size = 2) +
scale_y_continuous(sec.axis = sec_axis(~./16e4, name = "Genome Coverage (%)"))

# %%
ggarrange(fp.plot, filtered.plot, nrow = 2, align = "v")

ggarrange(fp.plot, filtered.plot, nrow = 2, align = "v") %>% 
    ggexport(filename = "./brainHint20FPCoverage.png")
# Out:
# file saved to ./brainHint20FPCoverage.png
# plot without title
